# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import os
from sklearn.metrics import confusion_matrix
import itertools
# Out:
# Using TensorFlow backend.

# %%
# Training parameters
batch_size = 64  # orig paper trained all networks with batch_size=128
epochs = 200
data_augmentation = True
num_classes = 10
version = 2
depth = 20


# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# %%
# Load the CIFAR10 data.
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %%
def categ(i):
  if i==0: 
      return "Aeroplane" 
  elif i==1: 
      return'Automobile' 
  elif i==2: 
      return'Bird' 
  elif i==3: 
      return'Cat' 
  elif i==4: 
      return'Deer' 
  elif i==5: 
      return'Dog' 
  elif i==6: 
      return'Frog' 
  elif i==7: 
      return'Horse' 
  elif i==8: 
      return 'Ship' 
  elif i==9: 
      return 'Truck' 
  else: 
      return 'Error'

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(X_train[i])
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(X_train[i+6])
plt.show()


for i in range(5):
  print("Labels {} : {}".format(i+1,categ(Y_train[i])))
for i in range(6,11):
  print("Labels {} : {}".format(i+1,categ(Y_train[i])))
# Out:
# Labels 1 : Frog
# Labels 2 : Truck
# Labels 3 : Truck
# Labels 4 : Deer
# Labels 5 : Automobile
# Labels 7 : Bird
# Labels 8 : Horse
# Labels 9 : Ship
# Labels 10 : Cat
# Labels 11 : Deer

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(X_test[i], interpolation='none')
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(X_test[i+6], interpolation='none')
plt.show()

for i in range(5):
  print("Labels {} : {}".format(i+1,categ(Y_test[i])))
for i in range(6,11):
  print("Labels {} : {}".format(i+1,categ(Y_test[i])))
# Out:
# Labels 1 : Cat
# Labels 2 : Ship
# Labels 3 : Ship
# Labels 4 : Aeroplane
# Labels 5 : Frog
# Labels 7 : Automobile
# Labels 8 : Frog
# Labels 9 : Cat
# Labels 10 : Automobile
# Labels 11 : Aeroplane

# %%
# Input image dimensions.
input_shape = X_train.shape[1:]

# Normalize data.
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    X_train_mean = np.mean(X_train, axis=0)
    X_train -= X_train_mean
    X_test -= X_train_mean

print('x_train shape:', X_train.shape)
print(Y_train.shape[0], 'train samples')
print(Y_test.shape[0], 'test samples')
print('y_train shape:', Y_train.shape)

# Convert class vectors to binary class matrices.
Y_train = keras.utils.to_categorical(Y_train, num_classes)
Y_test = keras.utils.to_categorical(Y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = resnet_v2(input_shape=input_shape, depth=depth)


model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)
# Out:
# Learning rate:  0.001
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   272         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 16)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   1088        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   1088        activation_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 64)   0           conv2d_5[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 64)   256         add_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 16)   1040        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 16)   64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 16)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 16)   2320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 16)   64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 16)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   1088        activation_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 64)   0           add_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 64)   256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 64)   4160        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  8320        add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  8320        activation_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 128)  0           conv2d_12[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 128)  512         add_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 64)   8256        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 64)   36928       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 128)  8320        activation_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 128)  0           add_3[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 128)  512         add_4[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 128)    16512       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 128)    512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 128)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 128)    147584      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 128)    512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 128)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 256)    33024       add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 256)    33024       activation_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 256)    0           conv2d_19[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 256)    1024        add_5[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 256)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 128)    32896       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 8, 128)    512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 128)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 128)    147584      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 128)    512         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 128)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 256)    33024       activation_18[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 256)    0           add_5[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 8, 8, 256)    1024        add_6[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 256)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 256)    0           activation_19[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 256)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           2570        flatten_1[0][0]
# ==================================================================================================
# Total params: 574,090
# Trainable params: 570,602
# Non-trainable params: 3,488
# __________________________________________________________________________________________________
# ResNet20v2

# %%
lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [lr_reducer, lr_scheduler]

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size = 0.1, random_state=42)

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    h =model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# Epoch 1/200
# Learning rate:  0.001
# 704/704 [==============================] - 73s 104ms/step - loss: 1.8336 - accuracy: 0.4662 - val_loss: 2.0294 - val_accuracy: 0.4456
# Epoch 2/200
# Learning rate:  0.001
# 704/704 [==============================] - 63s 89ms/step - loss: 1.4233 - accuracy: 0.6000 - val_loss: 1.7335 - val_accuracy: 0.5106
# Epoch 3/200
# Learning rate:  0.001
# 704/704 [==============================] - 63s 89ms/step - loss: 1.2433 - accuracy: 0.6557 - val_loss: 1.4965 - val_accuracy: 0.6006
# Epoch 4/200
# Learning rate:  0.001
# 704/704 [==============================] - 63s 89ms/step - loss: 1.1150 - accuracy: 0.7008 - val_loss: 1.2068 - val_accuracy: 0.6626
# Epoch 5/200
# Learning rate:  0.001
# 704/704 [==============================] - 63s 90ms/step - loss: 1.0233 - accuracy: 0.7303 - val_loss: 1.0596 - val_accuracy: 0.7220
# Epoch 6/200
# Learning rate:  0.001
# 704/704 [==============================] - 63s 89ms/step - loss: 0.9568 - accuracy: 0.7544 - val_loss: 0.9803 - val_accuracy: 0.7496
# Epoch 7/200
# Learning rate:  0.001
# 704/704 [==============================] - 63s 89ms/step - loss: 0.9141 - accuracy: 0.7653 - val_loss: 1.1094 - val_accuracy: 0.7244
# Epoch 8/200
# Learning rate:  0.001
# 704/704 [==============================] - 63s 89ms/step - loss: 0.8730 - accuracy: 0.7792 - val_loss: 0.9409 - val_accuracy: 0.7620
# Epoch 9/200
# Learning rate:  0.001
# 704/704 [==============================] - 63s 89ms/step - loss: 0.8367 - accuracy: 0.7914 - val_loss: 0.8536 - val_accuracy: 0.7836
# Epoch 10/200
# Learning rate:  0.001
# 704/704 [==============================] - 63s 89ms/step - loss: 0.8108 - accuracy: 0.7986 - val_loss: 0.9074 - val_accuracy: 0.7620
# Epoch 11/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.7864 - accuracy: 0.8059 - val_loss: 0.9540 - val_accuracy: 0.7650
# Epoch 12/200
# Learning rate:  0.001
# 704/704 [==============================] - 63s 89ms/step - loss: 0.7670 - accuracy: 0.8142 - val_loss: 1.0319 - val_accuracy: 0.7396
# Epoch 13/200
# Learning rate:  0.001
# 704/704 [==============================] - 63s 89ms/step - loss: 0.7458 - accuracy: 0.8196 - val_loss: 0.8355 - val_accuracy: 0.7954
# Epoch 14/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.7316 - accuracy: 0.8232 - val_loss: 0.8894 - val_accuracy: 0.7880
# Epoch 15/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.7114 - accuracy: 0.8295 - val_loss: 0.8259 - val_accuracy: 0.7940
# Epoch 16/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.6997 - accuracy: 0.8345 - val_loss: 0.9527 - val_accuracy: 0.7610
# Epoch 17/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.6866 - accuracy: 0.8396 - val_loss: 0.8862 - val_accuracy: 0.7848
# Epoch 18/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.6734 - accuracy: 0.8427 - val_loss: 0.9536 - val_accuracy: 0.7688
# Epoch 19/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.6722 - accuracy: 0.8431 - val_loss: 0.8115 - val_accuracy: 0.8124
# Epoch 20/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.6552 - accuracy: 0.8486 - val_loss: 0.8275 - val_accuracy: 0.7990
# Epoch 21/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.6420 - accuracy: 0.8534 - val_loss: 0.7729 - val_accuracy: 0.8086
# Epoch 22/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.6387 - accuracy: 0.8552 - val_loss: 0.8674 - val_accuracy: 0.7860
# Epoch 23/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.6263 - accuracy: 0.8584 - val_loss: 0.8725 - val_accuracy: 0.7806
# Epoch 24/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.6207 - accuracy: 0.8604 - val_loss: 0.8934 - val_accuracy: 0.7888
# Epoch 25/200
# Learning rate:  0.001
# 704/704 [==============================] - 63s 89ms/step - loss: 0.6121 - accuracy: 0.8630 - val_loss: 0.8436 - val_accuracy: 0.8104
# Epoch 26/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.6100 - accuracy: 0.8644 - val_loss: 0.9292 - val_accuracy: 0.7732
# Epoch 27/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.6053 - accuracy: 0.8656 - val_loss: 0.7412 - val_accuracy: 0.8234
# Epoch 28/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.5974 - accuracy: 0.8686 - val_loss: 0.7920 - val_accuracy: 0.8102
# Epoch 29/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.5869 - accuracy: 0.8720 - val_loss: 0.6740 - val_accuracy: 0.8458
# Epoch 30/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.5873 - accuracy: 0.8721 - val_loss: 0.8744 - val_accuracy: 0.7928
# Epoch 31/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.5780 - accuracy: 0.8751 - val_loss: 0.7256 - val_accuracy: 0.8404
# Epoch 32/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.5695 - accuracy: 0.8764 - val_loss: 0.8420 - val_accuracy: 0.8038
# Epoch 33/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.5723 - accuracy: 0.8761 - val_loss: 0.9264 - val_accuracy: 0.7860
# Epoch 34/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.5648 - accuracy: 0.8785 - val_loss: 0.7740 - val_accuracy: 0.8168
# Epoch 35/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.5628 - accuracy: 0.8810 - val_loss: 0.7145 - val_accuracy: 0.8414
# Epoch 36/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.5669 - accuracy: 0.8788 - val_loss: 0.7728 - val_accuracy: 0.8262
# Epoch 37/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.5579 - accuracy: 0.8819 - val_loss: 0.7829 - val_accuracy: 0.8210
# Epoch 38/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.5496 - accuracy: 0.8841 - val_loss: 0.8859 - val_accuracy: 0.7990
# Epoch 39/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.5426 - accuracy: 0.8879 - val_loss: 0.7825 - val_accuracy: 0.8188
# Epoch 40/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.5399 - accuracy: 0.8866 - val_loss: 0.7656 - val_accuracy: 0.8152
# Epoch 41/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.5328 - accuracy: 0.8907 - val_loss: 0.8237 - val_accuracy: 0.8042
# Epoch 42/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.5406 - accuracy: 0.8874 - val_loss: 0.8830 - val_accuracy: 0.7964
# Epoch 43/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.5334 - accuracy: 0.8898 - val_loss: 1.1957 - val_accuracy: 0.7364
# Epoch 44/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.5326 - accuracy: 0.8902 - val_loss: 0.8039 - val_accuracy: 0.8126
# Epoch 45/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.5289 - accuracy: 0.8895 - val_loss: 0.9700 - val_accuracy: 0.7762
# Epoch 46/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.5269 - accuracy: 0.8927 - val_loss: 0.6698 - val_accuracy: 0.8544
# Epoch 47/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.5232 - accuracy: 0.8938 - val_loss: 0.7192 - val_accuracy: 0.8394
# Epoch 48/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.5211 - accuracy: 0.8939 - val_loss: 0.8625 - val_accuracy: 0.8038
# Epoch 49/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.5257 - accuracy: 0.8921 - val_loss: 0.9443 - val_accuracy: 0.7828
# Epoch 50/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.5292 - accuracy: 0.8921 - val_loss: 0.7070 - val_accuracy: 0.8414
# Epoch 51/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.5090 - accuracy: 0.8983 - val_loss: 0.7909 - val_accuracy: 0.8324
# Epoch 52/200
# Learning rate:  0.001
# 704/704 [==============================] - 63s 89ms/step - loss: 0.5111 - accuracy: 0.8981 - val_loss: 1.0718 - val_accuracy: 0.7550
# Epoch 53/200
# Learning rate:  0.001
# 704/704 [==============================] - 63s 89ms/step - loss: 0.5174 - accuracy: 0.8960 - val_loss: 0.8398 - val_accuracy: 0.8138
# Epoch 54/200
# Learning rate:  0.001
# 704/704 [==============================] - 63s 89ms/step - loss: 0.5113 - accuracy: 0.8983 - val_loss: 0.6484 - val_accuracy: 0.8590
# Epoch 55/200
# Learning rate:  0.001
# 704/704 [==============================] - 63s 89ms/step - loss: 0.5065 - accuracy: 0.8987 - val_loss: 0.7233 - val_accuracy: 0.8404
# Epoch 56/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.5015 - accuracy: 0.9003 - val_loss: 0.7662 - val_accuracy: 0.8228
# Epoch 57/200
# Learning rate:  0.001
# 704/704 [==============================] - 63s 89ms/step - loss: 0.4989 - accuracy: 0.9007 - val_loss: 0.8032 - val_accuracy: 0.8290
# Epoch 58/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.4965 - accuracy: 0.9026 - val_loss: 0.9173 - val_accuracy: 0.7940
# Epoch 59/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.4935 - accuracy: 0.9034 - val_loss: 0.7169 - val_accuracy: 0.8294
# Epoch 60/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.5030 - accuracy: 0.8999 - val_loss: 0.6578 - val_accuracy: 0.8568
# Epoch 61/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.4949 - accuracy: 0.9025 - val_loss: 1.0275 - val_accuracy: 0.7898
# Epoch 62/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.4906 - accuracy: 0.9043 - val_loss: 0.6524 - val_accuracy: 0.8576
# Epoch 63/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.4927 - accuracy: 0.9018 - val_loss: 0.6521 - val_accuracy: 0.8570
# Epoch 64/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.4861 - accuracy: 0.9052 - val_loss: 0.8561 - val_accuracy: 0.8092
# Epoch 65/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.4881 - accuracy: 0.9044 - val_loss: 0.7548 - val_accuracy: 0.8420
# Epoch 66/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.4881 - accuracy: 0.9036 - val_loss: 0.7265 - val_accuracy: 0.8466
# Epoch 67/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.4832 - accuracy: 0.9041 - val_loss: 0.7429 - val_accuracy: 0.8340
# Epoch 68/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.4834 - accuracy: 0.9058 - val_loss: 0.7926 - val_accuracy: 0.8286
# Epoch 69/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.4800 - accuracy: 0.9064 - val_loss: 0.8378 - val_accuracy: 0.8190
# Epoch 70/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.4860 - accuracy: 0.9056 - val_loss: 0.7376 - val_accuracy: 0.8406
# Epoch 71/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.4812 - accuracy: 0.9071 - val_loss: 0.6463 - val_accuracy: 0.8642
# Epoch 72/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.4786 - accuracy: 0.9087 - val_loss: 0.6870 - val_accuracy: 0.8544
# Epoch 73/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.4761 - accuracy: 0.9078 - val_loss: 0.7415 - val_accuracy: 0.8374
# Epoch 74/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.4750 - accuracy: 0.9074 - val_loss: 0.8250 - val_accuracy: 0.8184
# Epoch 75/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.4755 - accuracy: 0.9090 - val_loss: 0.7261 - val_accuracy: 0.8380
# Epoch 76/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.4693 - accuracy: 0.9100 - val_loss: 0.6108 - val_accuracy: 0.8688
# Epoch 77/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.4676 - accuracy: 0.9108 - val_loss: 0.7059 - val_accuracy: 0.8506
# Epoch 78/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 88ms/step - loss: 0.4717 - accuracy: 0.9091 - val_loss: 0.9167 - val_accuracy: 0.7902
# Epoch 79/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.4703 - accuracy: 0.9105 - val_loss: 0.6366 - val_accuracy: 0.8588
# Epoch 80/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.4640 - accuracy: 0.9120 - val_loss: 0.8258 - val_accuracy: 0.8172
# Epoch 81/200
# Learning rate:  0.001
# 704/704 [==============================] - 62s 89ms/step - loss: 0.4619 - accuracy: 0.9129 - val_loss: 0.6800 - val_accuracy: 0.8500
# Epoch 82/200
# Learning rate:  0.0001
# 704/704 [==============================] - 65s 93ms/step - loss: 0.3842 - accuracy: 0.9418 - val_loss: 0.4816 - val_accuracy: 0.9068
# Epoch 83/200
# Learning rate:  0.0001
# 704/704 [==============================] - 63s 89ms/step - loss: 0.3518 - accuracy: 0.9510 - val_loss: 0.4661 - val_accuracy: 0.9110
# Epoch 84/200
# Learning rate:  0.0001
# 220/704 [========>.....................] - ETA: 41s - loss: 0.3380 - accuracy: 0.9555Buffered data was truncated after reaching the output size limit.

# %%
predictions = model.predict(X_test, verbose=1)
# Out:
# 10000/10000 [==============================] - 5s 483us/step

# %%
def test_accuracy():
    tp = []
    err = []
    t = 0
    #predictions = model.predict(x_test, verbose=1)
    for i in range(predictions.shape[0]):
        if (np.argmax(predictions[i]) == np.argmax(Y_test[i])):
            t = t+1
            tp.append(i)
        else:
            err.append(i)
    return t, float(t)*100/predictions.shape[0], err, tp

# %%
p = test_accuracy()
print("Test accuracy: {} %".format(p[1]))
# Out:
# Test accuracy: 90.98 %

# %%
final_loss, final_acc = model.evaluate(X_test, Y_test, verbose=0)
print("Final loss: {0:.6f}, final accuracy: {1:.6f}".format(final_loss, final_acc))
# Out:
# Final loss: 0.489885, final accuracy: 0.909800

# %%
import numpy as np
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Predict the values from the validation dataset
Y_pred = model.predict(X_test)
# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred, axis = 1) 
# Convert validation observations to one hot vectors
Y_true = np.argmax(Y_test, axis = 1) 
# compute the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
# plot the confusion matrix
plot_confusion_matrix(confusion_mtx, classes = range(10))

# %%
print(h.history.keys())
accuracy = h.history['accuracy']
val_accuracy = h.history['val_accuracy']
loss = h.history['loss']
val_loss = h.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.show()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy', 'lr'])

# %%
# Errors are difference between predicted labels and true labels
errors = (Y_pred_classes - Y_true != 0)

Y_pred_classes_errors = Y_pred_classes[errors]
Y_pred_errors = Y_pred[errors]
Y_true_errors = Y_true[errors]
X_val_errors = X_test[errors]

def display_errors(errors_index,img_errors,pred_errors, obs_errors):
    """ This function shows 6 images with their predicted and real labels"""
    n = 0
    nrows = 2
    ncols = 3
    fig, ax = plt.subplots(nrows,ncols,sharex=True)
    fig.tight_layout()
    for row in range(nrows):
        for col in range(ncols):
            error = errors_index[n]
            ax[row,col].imshow((img_errors[error]).reshape((32,32,3))*2)
            
            ax[row,col].set_title("\nPredicted:{}\nTrue label :{}".format(categ(pred_errors[error]),categ(obs_errors[error])))
            
            # subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=None)
            n += 1

# Probabilities of the wrong predicted numbers
Y_pred_errors_prob = np.max(Y_pred_errors,axis = 1)

# Predicted probabilities of the true values in the error set
true_prob_errors = np.diagonal(np.take(Y_pred_errors, Y_true_errors, axis=1))

# Difference between the probability of the predicted label and the true label
delta_pred_true_errors = Y_pred_errors_prob - true_prob_errors

# Sorted list of the delta prob errors
sorted_dela_errors = np.argsort(delta_pred_true_errors)

# Top 6 errors 
most_important_errors = sorted_dela_errors[-6:]

# Show the top 6 errors
display_errors(most_important_errors, X_val_errors, Y_pred_classes_errors, Y_true_errors)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
test_im = x_train[15]
plt.imshow(test_im.reshape(32,32,3)*2, cmap='viridis', interpolation='none')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from keras import models
layer_outputs = [layer.output for layer in model.layers[:8]]
activation_model = models.Model(input=model.input, output=layer_outputs)
activations = activation_model.predict(test_im.reshape(1,32,32,3))

initial_activation = activations[1]
plt.matshow(initial_activation[0, :, :, 4], cmap='viridis')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=[<tf.Tenso...)`
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
model.layers[:-1]
# Out:
# [<keras.engine.input_layer.InputLayer at 0x7fd70ed15630>,
#  <keras.layers.convolutional.Conv2D at 0x7fd70d1d5748>,
#  <keras.layers.normalization.BatchNormalization at 0x7fd70ed46748>,
#  <keras.layers.core.Activation at 0x7fd70d2694a8>,
#  <keras.layers.convolutional.Conv2D at 0x7fd70ed8db70>,
#  <keras.layers.normalization.BatchNormalization at 0x7fd7005c6978>,
#  <keras.layers.core.Activation at 0x7fd7005c6ac8>,
#  <keras.layers.convolutional.Conv2D at 0x7fd70d1f46d8>,
#  <keras.layers.normalization.BatchNormalization at 0x7fd70057d9e8>,
#  <keras.layers.core.Activation at 0x7fd70057db70>,
#  <keras.layers.convolutional.Conv2D at 0x7fd7005851d0>,
#  <keras.layers.convolutional.Conv2D at 0x7fd7005cf160>,
#  <keras.layers.merge.Add at 0x7fd700533be0>,
#  <keras.layers.normalization.BatchNormalization at 0x7fd70053e630>,
#  <keras.layers.core.Activation at 0x7fd70053eda0>,
#  <keras.layers.convolutional.Conv2D at 0x7fd700539048>,
#  <keras.layers.normalization.BatchNormalization at 0x7fd7004efbe0>,
#  <keras.layers.core.Activation at 0x7fd7174b7588>,
#  <keras.layers.convolutional.Conv2D at 0x7fd70053ee10>,
#  <keras.layers.normalization.BatchNormalization at 0x7fd70d3e52e8>,
#  <keras.layers.core.Activation at 0x7fd70d3ceba8>,
#  <keras.layers.convolutional.Conv2D at 0x7fd710debd30>,
#  <keras.layers.merge.Add at 0x7fd70d1e1390>,
#  <keras.layers.normalization.BatchNormalization at 0x7fd70ed50400>,
#  <keras.layers.core.Activation at 0x7fd70ed50128>,
#  <keras.layers.convolutional.Conv2D at 0x7fd70d1e1da0>,
#  <keras.layers.normalization.BatchNormalization at 0x7fd70ed9d470>,
#  <keras.layers.core.Activation at 0x7fd70ed9df60>,
#  <keras.layers.convolutional.Conv2D at 0x7fd70f22ce48>,
#  <keras.layers.normalization.BatchNormalization at 0x7fd70eda3898>,
#  <keras.layers.core.Activation at 0x7fd70eda3b00>,
#  <keras.layers.convolutional.Conv2D at 0x7fd70eda3358>,
#  <keras.layers.convolutional.Conv2D at 0x7fd70f522278>,
#  <keras.layers.merge.Add at 0x7fd70f3d65c0>,
#  <keras.layers.normalization.BatchNormalization at 0x7fd7004f6e10>,
#  <keras.layers.core.Activation at 0x7fd7004f6ba8>,
#  <keras.layers.convolutional.Conv2D at 0x7fd70f52d2b0>,
#  <keras.layers.normalization.BatchNormalization at 0x7fd70f4d6a20>,
#  <keras.layers.core.Activation at 0x7fd70f4d6ba8>,
#  <keras.layers.convolutional.Conv2D at 0x7fd70f3037b8>,
#  <keras.layers.normalization.BatchNormalization at 0x7fd70f272d30>,
#  <keras.layers.core.Activation at 0x7fd70f272f28>,
#  <keras.layers.convolutional.Conv2D at 0x7fd70f4df208>,
#  <keras.layers.merge.Add at 0x7fd70f2747b8>,
#  <keras.layers.normalization.BatchNormalization at 0x7fd70f2bd6a0>,
#  <keras.layers.core.Activation at 0x7fd70f2bde10>,
#  <keras.layers.convolutional.Conv2D at 0x7fd70f2742e8>,
#  <keras.layers.normalization.BatchNormalization at 0x7fd70f33ed68>,
#  <keras.layers.core.Activation at 0x7fd70f3447f0>,
#  <keras.layers.convolutional.Conv2D at 0x7fd70f2bde80>,
#  <keras.layers.normalization.BatchNormalization at 0x7fd70f380f60>,
#  <keras.layers.core.Activation at 0x7fd70f35fe48>,
#  <keras.layers.convolutional.Conv2D at 0x7fd70f35f9b0>,
#  <keras.layers.convolutional.Conv2D at 0x7fd70f344898>,
#  <keras.layers.merge.Add at 0x7fd70f3b4828>,
#  <keras.layers.normalization.BatchNormalization at 0x7fd70f389e80>,
#  <keras.layers.core.Activation at 0x7fd70f3897b8>,
#  <keras.layers.convolutional.Conv2D at 0x7fd70f3b4908>,
#  <keras.layers.normalization.BatchNormalization at 0x7fd70f3e4a20>,
#  <keras.layers.core.Activation at 0x7fd70f3e4ba8>,
#  <keras.layers.convolutional.Conv2D at 0x7fd70f3ba7b8>,
#  <keras.layers.normalization.BatchNormalization at 0x7fd70f3d7d30>,
#  <keras.layers.core.Activation at 0x7fd70f3d7f28>,
#  <keras.layers.convolutional.Conv2D at 0x7fd70f3d0208>,
#  <keras.layers.merge.Add at 0x7fd70f45b7b8>,
#  <keras.layers.normalization.BatchNormalization at 0x7fd70f45bb70>,
#  <keras.layers.core.Activation at 0x7fd70f472da0>,
#  <keras.layers.pooling.AveragePooling2D at 0x7fd70f4686a0>,
#  <keras.layers.core.Flatten at 0x7fd70f468518>]

# %%
layer_names = []
for layer in model.layers[:-1]:
    layer_names.append(layer.name) 
images_per_row = 16
for layer_name, layer_activation in zip(layer_names, activations):
    if layer_name.startswith('conv'):
        n_features = layer_activation.shape[-1]
        size = layer_activation.shape[1]
        n_cols = n_features // images_per_row
        display_grid = np.zeros((size * n_cols, images_per_row * size))
        for col in range(n_cols):
            for row in range(images_per_row):
                channel_image = layer_activation[0,:, :, col * images_per_row + row]
                channel_image -= channel_image.mean()
                channel_image /= channel_image.std()
                channel_image *= 64
                channel_image += 128
                channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                display_grid[col * size : (col + 1) * size,
                             row * size : (row + 1) * size] = channel_image
        scale = 1. / size
        plt.figure(figsize=(scale * display_grid.shape[1],
                            scale * display_grid.shape[0]))
        plt.title(layer_name)
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='viridis')

# %%
layer_names = []
for layer in model.layers[:-1]:
    layer_names.append(layer.name) 
images_per_row = 16
for layer_name, layer_activation in zip(layer_names, activations):
    if layer_name.startswith('batch'):
        n_features = layer_activation.shape[-1]
        size = layer_activation.shape[1]
        n_cols = n_features // images_per_row
        display_grid = np.zeros((size * n_cols, images_per_row * size))
        for col in range(n_cols):
            for row in range(images_per_row):
                channel_image = layer_activation[0,:, :, col * images_per_row + row]
                channel_image -= channel_image.mean()
                channel_image /= channel_image.std()
                channel_image *= 64
                channel_image += 128
                channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                display_grid[col * size : (col + 1) * size,
                             row * size : (row + 1) * size] = channel_image
        scale = 1. / size
        plt.figure(figsize=(scale * display_grid.shape[1],
                            scale * display_grid.shape[0]))
        plt.title(layer_name)
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='viridis')

# %%
layer_names = []
for layer in model.layers[:-1]:
    layer_names.append(layer.name) 
images_per_row = 16
for layer_name, layer_activation in zip(layer_names, activations):
    if layer_name.startswith('activation'):
        n_features = layer_activation.shape[-1]
        size = layer_activation.shape[1]
        n_cols = n_features // images_per_row
        display_grid = np.zeros((size * n_cols, images_per_row * size))
        for col in range(n_cols):
            for row in range(images_per_row):
                channel_image = layer_activation[0,:, :, col * images_per_row + row]
                channel_image -= channel_image.mean()
                channel_image /= channel_image.std()
                channel_image *= 64
                channel_image += 128
                channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                display_grid[col * size : (col + 1) * size,
                             row * size : (row + 1) * size] = channel_image
        scale = 1. / size
        plt.figure(figsize=(scale * display_grid.shape[1],
                            scale * display_grid.shape[0]))
        plt.title(layer_name)
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='viridis')

# %%
# Predict the values from the validation dataset
Y_pred = model.predict(X_test)
# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred, axis = 1)
Y_true_classes = np.argmax(Y_test, axis = 1)

# %%
Y_pred_classes[:5], Y_true_classes[:5]
# Out:
# (array([3, 8, 8, 0, 6]), array([3, 8, 8, 0, 6]))

# %%
from sklearn.metrics import classification_report
target_names = ["Class {}".format(i) for i in range(num_classes)]
print(classification_report(Y_true_classes, Y_pred_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.90      0.94      0.92      1000
#      Class 1       0.95      0.97      0.96      1000
#      Class 2       0.88      0.86      0.87      1000
#      Class 3       0.84      0.81      0.82      1000
#      Class 4       0.91      0.92      0.91      1000
#      Class 5       0.87      0.86      0.87      1000
#      Class 6       0.90      0.95      0.92      1000
#      Class 7       0.96      0.91      0.94      1000
#      Class 8       0.95      0.94      0.94      1000
#      Class 9       0.94      0.94      0.94      1000
#
#     accuracy                           0.91     10000
#    macro avg       0.91      0.91      0.91     10000
# weighted avg       0.91      0.91      0.91     10000

# %%
from keras.models import load_model 
model.save('drive/My Drive/ResNet20_CIFAR10_Nice_V2.h5')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
