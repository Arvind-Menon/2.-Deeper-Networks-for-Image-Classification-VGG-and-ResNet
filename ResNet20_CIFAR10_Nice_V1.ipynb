# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import os
from sklearn.metrics import confusion_matrix
import itertools
# Out:
# Using TensorFlow backend.

# %%
# Training parameters
batch_size = 64  
epochs = 200
data_augmentation = True
num_classes = 10
version = 1
depth = 20


# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True


# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# %%
# Load the CIFAR10 data.
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %%
def categ(i):
  if i==0: 
      return "Aeroplane" 
  elif i==1: 
      return'Automobile' 
  elif i==2: 
      return'Bird' 
  elif i==3: 
      return'Cat' 
  elif i==4: 
      return'Deer' 
  elif i==5: 
      return'Dog' 
  elif i==6: 
      return'Frog' 
  elif i==7: 
      return'Horse' 
  elif i==8: 
      return 'Ship' 
  elif i==9: 
      return 'Truck' 
  else: 
      return 'Error'

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(X_train[i])
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(X_train[i+6])
plt.show()


for i in range(5):
  print("Labels {} : {}".format(i+1,categ(Y_train[i])))
for i in range(6,11):
  print("Labels {} : {}".format(i+1,categ(Y_train[i])))
# Out:
# Labels 1 : Frog
# Labels 2 : Truck
# Labels 3 : Truck
# Labels 4 : Deer
# Labels 5 : Automobile
# Labels 7 : Bird
# Labels 8 : Horse
# Labels 9 : Ship
# Labels 10 : Cat
# Labels 11 : Deer

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(X_test[i], interpolation='none')
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(X_test[i+6], interpolation='none')
plt.show()

for i in range(5):
  print("Labels {} : {}".format(i+1,categ(Y_test[i])))
for i in range(6,11):
  print("Labels {} : {}".format(i+1,categ(Y_test[i])))
# Out:
# Labels 1 : Cat
# Labels 2 : Ship
# Labels 3 : Ship
# Labels 4 : Aeroplane
# Labels 5 : Frog
# Labels 7 : Automobile
# Labels 8 : Frog
# Labels 9 : Cat
# Labels 10 : Automobile
# Labels 11 : Aeroplane

# %%
# Input image dimensions.
input_shape = X_train.shape[1:]

# Normalize data.
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    X_train_mean = np.mean(X_train, axis=0)
    X_train -= X_train_mean
    X_test -= X_train_mean

print('x_train shape:', X_train.shape)
print(Y_train.shape[0], 'train samples')
print(Y_test.shape[0], 'test samples')
print('y_train shape:', Y_train.shape)

# Convert class vectors to binary class matrices.
Y_train = keras.utils.to_categorical(Y_train, num_classes)
Y_test = keras.utils.to_categorical(Y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = resnet_v1(input_shape=input_shape, depth=depth)


model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)
# Out:
# Learning rate:  0.001
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 16)   0           activation_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 16)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 16)   2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 16)   64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 16)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 16)   2320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 16)   64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 16)   0           activation_3[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 16)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 16)   2320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 16)   64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 16)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 16)   2320        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 16)   64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 16)   0           activation_5[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 16)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 32)   4640        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 32)   128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 32)   544         activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 32)   0           conv2d_10[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 32)   0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 32)   9248        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 32)   128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 32)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 32)   9248        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 32)   128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 32)   0           activation_9[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 32)   0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 32)   9248        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 32)   128         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 32)   9248        activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 32)   128         conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 32)   0           activation_11[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 32)   0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 64)     18496       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 64)     256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 64)     0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 64)     36928       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 64)     2112        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 64)     256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 64)     0           conv2d_17[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 64)     0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 64)     36928       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 64)     256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 64)     0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 64)     36928       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 8, 64)     256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 64)     0           activation_15[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 64)     0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 64)     36928       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 64)     256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 64)     0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 64)     36928       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 8, 8, 64)     256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 8, 8, 64)     0           activation_17[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 64)     0           add_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 64)     0           activation_19[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 64)           0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           650         flatten_1[0][0]
# ==================================================================================================
# Total params: 274,442
# Trainable params: 273,066
# Non-trainable params: 1,376
# __________________________________________________________________________________________________
# ResNet20v1

# %%
# Prepare callbacks for model saving and for learning rate adjustment.
# checkpoint = ModelCheckpoint(filepath='drive/My Drive/',
#                              monitor='val_accuracy',
#                              verbose=1,
#                              save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [lr_reducer, lr_scheduler]

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size = 0.1, random_state=42)

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    h =model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# Epoch 1/200
# Learning rate:  0.001
# 704/704 [==============================] - 48s 68ms/step - loss: 1.6315 - accuracy: 0.4690 - val_loss: 1.4917 - val_accuracy: 0.5272
# Epoch 2/200
# Learning rate:  0.001
# 704/704 [==============================] - 36s 51ms/step - loss: 1.2411 - accuracy: 0.6080 - val_loss: 2.3888 - val_accuracy: 0.4122
# Epoch 3/200
# Learning rate:  0.001
# 704/704 [==============================] - 36s 51ms/step - loss: 1.0635 - accuracy: 0.6770 - val_loss: 1.3348 - val_accuracy: 0.6038
# Epoch 4/200
# Learning rate:  0.001
# 704/704 [==============================] - 37s 52ms/step - loss: 0.9532 - accuracy: 0.7207 - val_loss: 1.0910 - val_accuracy: 0.6792
# Epoch 5/200
# Learning rate:  0.001
# 704/704 [==============================] - 37s 52ms/step - loss: 0.8830 - accuracy: 0.7450 - val_loss: 1.5068 - val_accuracy: 0.5886
# Epoch 6/200
# Learning rate:  0.001
# 704/704 [==============================] - 37s 52ms/step - loss: 0.8257 - accuracy: 0.7656 - val_loss: 1.1542 - val_accuracy: 0.6696
# Epoch 7/200
# Learning rate:  0.001
# 704/704 [==============================] - 37s 52ms/step - loss: 0.7915 - accuracy: 0.7795 - val_loss: 1.0606 - val_accuracy: 0.7180
# Epoch 8/200
# Learning rate:  0.001
# 704/704 [==============================] - 37s 52ms/step - loss: 0.7486 - accuracy: 0.7960 - val_loss: 1.1825 - val_accuracy: 0.6708
# Epoch 9/200
# Learning rate:  0.001
# 704/704 [==============================] - 36s 52ms/step - loss: 0.7227 - accuracy: 0.8044 - val_loss: 0.9176 - val_accuracy: 0.7412
# Epoch 10/200
# Learning rate:  0.001
# 704/704 [==============================] - 36s 51ms/step - loss: 0.6943 - accuracy: 0.8144 - val_loss: 1.0069 - val_accuracy: 0.7208
# Epoch 11/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.6705 - accuracy: 0.8244 - val_loss: 0.8864 - val_accuracy: 0.7530
# Epoch 12/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.6586 - accuracy: 0.8286 - val_loss: 0.7531 - val_accuracy: 0.7908
# Epoch 13/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.6434 - accuracy: 0.8357 - val_loss: 0.8778 - val_accuracy: 0.7684
# Epoch 14/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.6286 - accuracy: 0.8389 - val_loss: 1.1242 - val_accuracy: 0.7104
# Epoch 15/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.6096 - accuracy: 0.8458 - val_loss: 0.8449 - val_accuracy: 0.7804
# Epoch 16/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.6018 - accuracy: 0.8509 - val_loss: 0.8579 - val_accuracy: 0.7820
# Epoch 17/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.5872 - accuracy: 0.8540 - val_loss: 0.6561 - val_accuracy: 0.8382
# Epoch 18/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.5823 - accuracy: 0.8558 - val_loss: 0.9745 - val_accuracy: 0.7582
# Epoch 19/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.5703 - accuracy: 0.8607 - val_loss: 0.7466 - val_accuracy: 0.8026
# Epoch 20/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.5626 - accuracy: 0.8638 - val_loss: 0.8336 - val_accuracy: 0.7940
# Epoch 21/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.5558 - accuracy: 0.8666 - val_loss: 0.9534 - val_accuracy: 0.7692
# Epoch 22/200
# Learning rate:  0.001
# 704/704 [==============================] - 36s 51ms/step - loss: 0.5496 - accuracy: 0.8690 - val_loss: 0.7507 - val_accuracy: 0.8070
# Epoch 23/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.5409 - accuracy: 0.8740 - val_loss: 0.7707 - val_accuracy: 0.8120
# Epoch 24/200
# Learning rate:  0.001
# 704/704 [==============================] - 36s 51ms/step - loss: 0.5402 - accuracy: 0.8722 - val_loss: 0.7305 - val_accuracy: 0.8086
# Epoch 25/200
# Learning rate:  0.001
# 704/704 [==============================] - 36s 51ms/step - loss: 0.5321 - accuracy: 0.8758 - val_loss: 0.7115 - val_accuracy: 0.8266
# Epoch 26/200
# Learning rate:  0.001
# 704/704 [==============================] - 36s 52ms/step - loss: 0.5225 - accuracy: 0.8790 - val_loss: 0.7265 - val_accuracy: 0.8156
# Epoch 27/200
# Learning rate:  0.001
# 704/704 [==============================] - 37s 52ms/step - loss: 0.5269 - accuracy: 0.8763 - val_loss: 0.8677 - val_accuracy: 0.7954
# Epoch 28/200
# Learning rate:  0.001
# 704/704 [==============================] - 36s 51ms/step - loss: 0.5178 - accuracy: 0.8798 - val_loss: 0.7710 - val_accuracy: 0.8142
# Epoch 29/200
# Learning rate:  0.001
# 704/704 [==============================] - 36s 51ms/step - loss: 0.5173 - accuracy: 0.8805 - val_loss: 0.7016 - val_accuracy: 0.8326
# Epoch 30/200
# Learning rate:  0.001
# 704/704 [==============================] - 38s 54ms/step - loss: 0.5116 - accuracy: 0.8829 - val_loss: 0.7825 - val_accuracy: 0.8088
# Epoch 31/200
# Learning rate:  0.001
# 704/704 [==============================] - 37s 52ms/step - loss: 0.5056 - accuracy: 0.8866 - val_loss: 0.7850 - val_accuracy: 0.8132
# Epoch 32/200
# Learning rate:  0.001
# 704/704 [==============================] - 37s 52ms/step - loss: 0.5000 - accuracy: 0.8886 - val_loss: 0.6919 - val_accuracy: 0.8362
# Epoch 33/200
# Learning rate:  0.001
# 704/704 [==============================] - 37s 53ms/step - loss: 0.5037 - accuracy: 0.8862 - val_loss: 0.7508 - val_accuracy: 0.8226
# Epoch 34/200
# Learning rate:  0.001
# 704/704 [==============================] - 37s 53ms/step - loss: 0.4923 - accuracy: 0.8909 - val_loss: 0.7635 - val_accuracy: 0.8156
# Epoch 35/200
# Learning rate:  0.001
# 704/704 [==============================] - 37s 52ms/step - loss: 0.4927 - accuracy: 0.8915 - val_loss: 0.6870 - val_accuracy: 0.8336
# Epoch 36/200
# Learning rate:  0.001
# 704/704 [==============================] - 36s 52ms/step - loss: 0.4899 - accuracy: 0.8927 - val_loss: 0.7415 - val_accuracy: 0.8270
# Epoch 37/200
# Learning rate:  0.001
# 704/704 [==============================] - 36s 51ms/step - loss: 0.4862 - accuracy: 0.8942 - val_loss: 0.6795 - val_accuracy: 0.8418
# Epoch 38/200
# Learning rate:  0.001
# 704/704 [==============================] - 36s 50ms/step - loss: 0.4803 - accuracy: 0.8952 - val_loss: 0.8658 - val_accuracy: 0.7978
# Epoch 39/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.4831 - accuracy: 0.8950 - val_loss: 0.6800 - val_accuracy: 0.8370
# Epoch 40/200
# Learning rate:  0.001
# 704/704 [==============================] - 36s 51ms/step - loss: 0.4780 - accuracy: 0.8966 - val_loss: 0.7557 - val_accuracy: 0.8204
# Epoch 41/200
# Learning rate:  0.001
# 704/704 [==============================] - 36s 51ms/step - loss: 0.4852 - accuracy: 0.8947 - val_loss: 0.6036 - val_accuracy: 0.8584
# Epoch 42/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.4707 - accuracy: 0.9000 - val_loss: 0.6950 - val_accuracy: 0.8374
# Epoch 43/200
# Learning rate:  0.001
# 704/704 [==============================] - 36s 50ms/step - loss: 0.4780 - accuracy: 0.8971 - val_loss: 0.6315 - val_accuracy: 0.8548
# Epoch 44/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.4719 - accuracy: 0.8998 - val_loss: 0.6286 - val_accuracy: 0.8576
# Epoch 45/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.4681 - accuracy: 0.8999 - val_loss: 0.6464 - val_accuracy: 0.8482
# Epoch 46/200
# Learning rate:  0.001
# 704/704 [==============================] - 34s 49ms/step - loss: 0.4588 - accuracy: 0.9026 - val_loss: 0.7607 - val_accuracy: 0.8214
# Epoch 47/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.4682 - accuracy: 0.9009 - val_loss: 0.6417 - val_accuracy: 0.8512
# Epoch 48/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.4640 - accuracy: 0.9022 - val_loss: 0.9192 - val_accuracy: 0.7944
# Epoch 49/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.4655 - accuracy: 0.9025 - val_loss: 0.7396 - val_accuracy: 0.8282
# Epoch 50/200
# Learning rate:  0.001
# 704/704 [==============================] - 34s 49ms/step - loss: 0.4552 - accuracy: 0.9045 - val_loss: 0.8786 - val_accuracy: 0.7958
# Epoch 51/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.4647 - accuracy: 0.9029 - val_loss: 0.6030 - val_accuracy: 0.8604
# Epoch 52/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.4532 - accuracy: 0.9064 - val_loss: 0.8279 - val_accuracy: 0.8102
# Epoch 53/200
# Learning rate:  0.001
# 704/704 [==============================] - 34s 49ms/step - loss: 0.4575 - accuracy: 0.9046 - val_loss: 0.6785 - val_accuracy: 0.8356
# Epoch 54/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.4519 - accuracy: 0.9084 - val_loss: 0.6829 - val_accuracy: 0.8404
# Epoch 55/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.4523 - accuracy: 0.9083 - val_loss: 0.7446 - val_accuracy: 0.8248
# Epoch 56/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.4539 - accuracy: 0.9059 - val_loss: 0.7137 - val_accuracy: 0.8290
# Epoch 57/200
# Learning rate:  0.001
# 704/704 [==============================] - 34s 49ms/step - loss: 0.4503 - accuracy: 0.9081 - val_loss: 0.6416 - val_accuracy: 0.8574
# Epoch 58/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.4566 - accuracy: 0.9056 - val_loss: 0.6519 - val_accuracy: 0.8474
# Epoch 59/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.4459 - accuracy: 0.9104 - val_loss: 0.6061 - val_accuracy: 0.8618
# Epoch 60/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.4550 - accuracy: 0.9073 - val_loss: 0.6158 - val_accuracy: 0.8572
# Epoch 61/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.4441 - accuracy: 0.9116 - val_loss: 0.7628 - val_accuracy: 0.8250
# Epoch 62/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.4497 - accuracy: 0.9090 - val_loss: 0.8075 - val_accuracy: 0.8250
# Epoch 63/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.4484 - accuracy: 0.9092 - val_loss: 0.6226 - val_accuracy: 0.8568
# Epoch 64/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.4430 - accuracy: 0.9132 - val_loss: 0.5873 - val_accuracy: 0.8704
# Epoch 65/200
# Learning rate:  0.001
# 704/704 [==============================] - 36s 51ms/step - loss: 0.4405 - accuracy: 0.9123 - val_loss: 1.0318 - val_accuracy: 0.7562
# Epoch 66/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.4410 - accuracy: 0.9122 - val_loss: 0.7333 - val_accuracy: 0.8348
# Epoch 67/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.4381 - accuracy: 0.9114 - val_loss: 0.7350 - val_accuracy: 0.8256
# Epoch 68/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.4396 - accuracy: 0.9142 - val_loss: 0.6845 - val_accuracy: 0.8436
# Epoch 69/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.4369 - accuracy: 0.9129 - val_loss: 0.6227 - val_accuracy: 0.8632
# Epoch 70/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.4353 - accuracy: 0.9134 - val_loss: 0.7868 - val_accuracy: 0.8254
# Epoch 71/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.4430 - accuracy: 0.9124 - val_loss: 0.6224 - val_accuracy: 0.8704
# Epoch 72/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.4367 - accuracy: 0.9144 - val_loss: 0.5879 - val_accuracy: 0.8720
# Epoch 73/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.4351 - accuracy: 0.9147 - val_loss: 0.7691 - val_accuracy: 0.8302
# Epoch 74/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.4434 - accuracy: 0.9121 - val_loss: 0.8214 - val_accuracy: 0.8126
# Epoch 75/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.4342 - accuracy: 0.9147 - val_loss: 0.6053 - val_accuracy: 0.8656
# Epoch 76/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.4279 - accuracy: 0.9163 - val_loss: 0.6935 - val_accuracy: 0.8510
# Epoch 77/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.4299 - accuracy: 0.9161 - val_loss: 0.6717 - val_accuracy: 0.8384
# Epoch 78/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.4337 - accuracy: 0.9163 - val_loss: 0.6326 - val_accuracy: 0.8578
# Epoch 79/200
# Learning rate:  0.001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.4259 - accuracy: 0.9193 - val_loss: 0.6583 - val_accuracy: 0.8516
# Epoch 80/200
# Learning rate:  0.001
# 704/704 [==============================] - 34s 49ms/step - loss: 0.4287 - accuracy: 0.9176 - val_loss: 0.6780 - val_accuracy: 0.8454
# Epoch 81/200
# Learning rate:  0.001
# 704/704 [==============================] - 34s 49ms/step - loss: 0.4287 - accuracy: 0.9187 - val_loss: 0.6113 - val_accuracy: 0.8680
# Epoch 82/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.3589 - accuracy: 0.9423 - val_loss: 0.4822 - val_accuracy: 0.9056
# Epoch 83/200
# Learning rate:  0.0001
# 704/704 [==============================] - 34s 49ms/step - loss: 0.3286 - accuracy: 0.9530 - val_loss: 0.4789 - val_accuracy: 0.9052
# Epoch 84/200
# Learning rate:  0.0001
# 704/704 [==============================] - 34s 49ms/step - loss: 0.3147 - accuracy: 0.9567 - val_loss: 0.4822 - val_accuracy: 0.9052
# Epoch 85/200
# Learning rate:  0.0001
# 704/704 [==============================] - 34s 49ms/step - loss: 0.3030 - accuracy: 0.9606 - val_loss: 0.4785 - val_accuracy: 0.9046
# Epoch 86/200
# Learning rate:  0.0001
# 704/704 [==============================] - 34s 49ms/step - loss: 0.2970 - accuracy: 0.9609 - val_loss: 0.4789 - val_accuracy: 0.9064
# Epoch 87/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.2885 - accuracy: 0.9637 - val_loss: 0.4774 - val_accuracy: 0.9062
# Epoch 88/200
# Learning rate:  0.0001
# 704/704 [==============================] - 34s 49ms/step - loss: 0.2835 - accuracy: 0.9646 - val_loss: 0.4784 - val_accuracy: 0.9058
# Epoch 89/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.2801 - accuracy: 0.9647 - val_loss: 0.4745 - val_accuracy: 0.9058
# Epoch 90/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.2748 - accuracy: 0.9660 - val_loss: 0.4996 - val_accuracy: 0.9028
# Epoch 91/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.2709 - accuracy: 0.9674 - val_loss: 0.4804 - val_accuracy: 0.9090
# Epoch 92/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.2631 - accuracy: 0.9690 - val_loss: 0.4791 - val_accuracy: 0.9060
# Epoch 93/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.2607 - accuracy: 0.9688 - val_loss: 0.4858 - val_accuracy: 0.9072
# Epoch 94/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.2545 - accuracy: 0.9707 - val_loss: 0.4863 - val_accuracy: 0.9076
# Epoch 95/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.2524 - accuracy: 0.9700 - val_loss: 0.4851 - val_accuracy: 0.9070
# Epoch 96/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.2502 - accuracy: 0.9711 - val_loss: 0.4885 - val_accuracy: 0.9062
# Epoch 97/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.2463 - accuracy: 0.9728 - val_loss: 0.4881 - val_accuracy: 0.9060
# Epoch 98/200
# Learning rate:  0.0001
# 704/704 [==============================] - 36s 51ms/step - loss: 0.2428 - accuracy: 0.9726 - val_loss: 0.4923 - val_accuracy: 0.9072
# Epoch 99/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.2417 - accuracy: 0.9720 - val_loss: 0.4854 - val_accuracy: 0.9098
# Epoch 100/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.2363 - accuracy: 0.9748 - val_loss: 0.4835 - val_accuracy: 0.9086
# Epoch 101/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.2367 - accuracy: 0.9739 - val_loss: 0.4749 - val_accuracy: 0.9096
# Epoch 102/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.2292 - accuracy: 0.9753 - val_loss: 0.4902 - val_accuracy: 0.9070
# Epoch 103/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.2279 - accuracy: 0.9758 - val_loss: 0.5058 - val_accuracy: 0.9038
# Epoch 104/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.2242 - accuracy: 0.9760 - val_loss: 0.4818 - val_accuracy: 0.9108
# Epoch 105/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.2235 - accuracy: 0.9761 - val_loss: 0.4883 - val_accuracy: 0.9092
# Epoch 106/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.2220 - accuracy: 0.9764 - val_loss: 0.4750 - val_accuracy: 0.9090
# Epoch 107/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 50ms/step - loss: 0.2219 - accuracy: 0.9764 - val_loss: 0.4787 - val_accuracy: 0.9076
# Epoch 108/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.2179 - accuracy: 0.9767 - val_loss: 0.4854 - val_accuracy: 0.9088
# Epoch 109/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.2150 - accuracy: 0.9782 - val_loss: 0.5111 - val_accuracy: 0.9016
# Epoch 110/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.2123 - accuracy: 0.9782 - val_loss: 0.4926 - val_accuracy: 0.9060
# Epoch 111/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.2072 - accuracy: 0.9798 - val_loss: 0.4912 - val_accuracy: 0.9064
# Epoch 112/200
# Learning rate:  0.0001
# 704/704 [==============================] - 34s 49ms/step - loss: 0.2067 - accuracy: 0.9799 - val_loss: 0.4815 - val_accuracy: 0.9134
# Epoch 113/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.2066 - accuracy: 0.9788 - val_loss: 0.5113 - val_accuracy: 0.9040
# Epoch 114/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.2053 - accuracy: 0.9801 - val_loss: 0.5020 - val_accuracy: 0.9056
# Epoch 115/200
# Learning rate:  0.0001
# 704/704 [==============================] - 34s 49ms/step - loss: 0.2040 - accuracy: 0.9794 - val_loss: 0.4904 - val_accuracy: 0.9068
# Epoch 116/200
# Learning rate:  0.0001
# 704/704 [==============================] - 34s 49ms/step - loss: 0.1994 - accuracy: 0.9807 - val_loss: 0.5046 - val_accuracy: 0.9030
# Epoch 117/200
# Learning rate:  0.0001
# 704/704 [==============================] - 34s 49ms/step - loss: 0.1990 - accuracy: 0.9809 - val_loss: 0.4928 - val_accuracy: 0.9080
# Epoch 118/200
# Learning rate:  0.0001
# 704/704 [==============================] - 34s 49ms/step - loss: 0.1956 - accuracy: 0.9811 - val_loss: 0.4863 - val_accuracy: 0.9080
# Epoch 119/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.1972 - accuracy: 0.9802 - val_loss: 0.5017 - val_accuracy: 0.9062
# Epoch 120/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.1917 - accuracy: 0.9819 - val_loss: 0.5217 - val_accuracy: 0.9034
# Epoch 121/200
# Learning rate:  0.0001
# 704/704 [==============================] - 35s 49ms/step - loss: 0.1928 - accuracy: 0.9806 - val_loss: 0.5078 - val_accuracy: 0.9028
# Epoch 122/200
# Learning rate:  1e-05
# 704/704 [==============================] - 35s 49ms/step - loss: 0.1858 - accuracy: 0.9835 - val_loss: 0.4922 - val_accuracy: 0.9072
# Epoch 123/200
# Learning rate:  1e-05
# 704/704 [==============================] - 35s 49ms/step - loss: 0.1851 - accuracy: 0.9845 - val_loss: 0.4868 - val_accuracy: 0.9098
# Epoch 124/200
# Learning rate:  1e-05
# 704/704 [==============================] - 35s 49ms/step - loss: 0.1834 - accuracy: 0.9849 - val_loss: 0.4868 - val_accuracy: 0.9094
# Epoch 125/200
# Learning rate:  1e-05
# 587/704 [========================>.....] - ETA: 5s - loss: 0.1835 - accuracy: 0.9849Buffered data was truncated after reaching the output size limit.

# %%
predictions = model.predict(X_test, verbose=1)
# Out:
# 10000/10000 [==============================] - 2s 196us/step

# %%
def test_accuracy():
    tp = []
    err = []
    t = 0
    #predictions = model.predict(x_test, verbose=1)
    for i in range(predictions.shape[0]):
        if (np.argmax(predictions[i]) == np.argmax(Y_test[i])):
            t = t+1
            tp.append(i)
        else:
            err.append(i)
    return t, float(t)*100/predictions.shape[0], err, tp

# %%
p = test_accuracy()
print("Test accuracy: {} %".format(p[1]))
# Out:
# Test accuracy: 90.56 %

# %%
final_loss, final_acc = model.evaluate(X_test, Y_test, verbose=0)
print("Final loss: {0:.6f}, final accuracy: {1:.6f}".format(final_loss, final_acc))
# Out:
# Final loss: 0.517815, final accuracy: 0.905600

# %%
# Look at confusion matrix 
#Note, this code is taken straight from the SKLEARN website, an nice way of viewing confusion matrix.
import numpy as np
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Predict the values from the validation dataset
Y_pred = model.predict(X_test)
# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred, axis = 1) 
# Convert validation observations to one hot vectors
Y_true = np.argmax(Y_test, axis = 1) 
# compute the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
# plot the confusion matrix
plot_confusion_matrix(confusion_mtx, classes = range(10))

# %%
print(h.history.keys())
accuracy = h.history['accuracy']
val_accuracy = h.history['val_accuracy']
loss = h.history['loss']
val_loss = h.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.show()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy', 'lr'])

# %%
# Errors are difference between predicted labels and true labels
errors = (Y_pred_classes - Y_true != 0)

Y_pred_classes_errors = Y_pred_classes[errors]
Y_pred_errors = Y_pred[errors]
Y_true_errors = Y_true[errors]
X_val_errors = X_test[errors]

def display_errors(errors_index,img_errors,pred_errors, obs_errors):
    """ This function shows 6 images with their predicted and real labels"""
    n = 0
    nrows = 2
    ncols = 3
    fig, ax = plt.subplots(nrows,ncols,sharex=True)
    fig.tight_layout()
    for row in range(nrows):
        for col in range(ncols):
            error = errors_index[n]
            ax[row,col].imshow((img_errors[error]).reshape((32,32,3))*2)
            
            ax[row,col].set_title("\nPredicted label :{}\nTrue label :{}".format(categ(pred_errors[error]),categ(obs_errors[error])))
            
            # subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=None)
            n += 1

# Probabilities of the wrong predicted numbers
Y_pred_errors_prob = np.max(Y_pred_errors,axis = 1)

# Predicted probabilities of the true values in the error set
true_prob_errors = np.diagonal(np.take(Y_pred_errors, Y_true_errors, axis=1))

# Difference between the probability of the predicted label and the true label
delta_pred_true_errors = Y_pred_errors_prob - true_prob_errors

# Sorted list of the delta prob errors
sorted_dela_errors = np.argsort(delta_pred_true_errors)

# Top 6 errors 
most_important_errors = sorted_dela_errors[-6:]

# Show the top 6 errors
display_errors(most_important_errors, X_val_errors, Y_pred_classes_errors, Y_true_errors)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
test_im = x_train[15]
plt.imshow(test_im.reshape(32,32,3)*2, cmap='viridis', interpolation='none')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from keras import models
layer_outputs = [layer.output for layer in model.layers[:8]]
activation_model = models.Model(input=model.input, output=layer_outputs)
activations = activation_model.predict(test_im.reshape(1,32,32,3))

initial_activation = activations[1]
plt.matshow(initial_activation[0, :, :, 4], cmap='viridis')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=[<tf.Tenso...)`
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
model.layers[:-1]
# Out:
# [<keras.engine.input_layer.InputLayer at 0x7f2b3bc37b00>,
#  <keras.layers.convolutional.Conv2D at 0x7f2b3bc3d9b0>,
#  <keras.layers.normalization.BatchNormalization at 0x7f2b3bc0b518>,
#  <keras.layers.core.Activation at 0x7f2b3dc4f048>,
#  <keras.layers.convolutional.Conv2D at 0x7f2b3bc3de80>,
#  <keras.layers.normalization.BatchNormalization at 0x7f2b3e9f8908>,
#  <keras.layers.core.Activation at 0x7f2b300ec0f0>,
#  <keras.layers.convolutional.Conv2D at 0x7f2b300f9630>,
#  <keras.layers.normalization.BatchNormalization at 0x7f2b3008d1d0>,
#  <keras.layers.merge.Add at 0x7f2b3009f208>,
#  <keras.layers.core.Activation at 0x7f2b300acc50>,
#  <keras.layers.convolutional.Conv2D at 0x7f2b300ac4a8>,
#  <keras.layers.normalization.BatchNormalization at 0x7f2b300c3d30>,
#  <keras.layers.core.Activation at 0x7f2b30051b00>,
#  <keras.layers.convolutional.Conv2D at 0x7f2b3005ed30>,
#  <keras.layers.normalization.BatchNormalization at 0x7f2b30079400>,
#  <keras.layers.merge.Add at 0x7f2b30086470>,
#  <keras.layers.core.Activation at 0x7f2b300155f8>,
#  <keras.layers.convolutional.Conv2D at 0x7f2b30015978>,
#  <keras.layers.normalization.BatchNormalization at 0x7f2b3bee3a90>,
#  <keras.layers.core.Activation at 0x7f2b3be56dd8>,
#  <keras.layers.convolutional.Conv2D at 0x7f2b3fb8e400>,
#  <keras.layers.normalization.BatchNormalization at 0x7f2b3be68208>,
#  <keras.layers.merge.Add at 0x7f2b3d7636a0>,
#  <keras.layers.core.Activation at 0x7f2b3dcbe2b0>,
#  <keras.layers.convolutional.Conv2D at 0x7f2b3dcbea90>,
#  <keras.layers.normalization.BatchNormalization at 0x7f2b978942e8>,
#  <keras.layers.core.Activation at 0x7f2b3d795c50>,
#  <keras.layers.convolutional.Conv2D at 0x7f2b3dc4f1d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f2b3d744278>,
#  <keras.layers.normalization.BatchNormalization at 0x7f2b3d7b57f0>,
#  <keras.layers.merge.Add at 0x7f2b3d7995f8>,
#  <keras.layers.core.Activation at 0x7f2b3d73cda0>,
#  <keras.layers.convolutional.Conv2D at 0x7f2b3d73c898>,
#  <keras.layers.normalization.BatchNormalization at 0x7f2b3de15e48>,
#  <keras.layers.core.Activation at 0x7f2b3de157b8>,
#  <keras.layers.convolutional.Conv2D at 0x7f2b3de15f98>,
#  <keras.layers.normalization.BatchNormalization at 0x7f2b3dd42fd0>,
#  <keras.layers.merge.Add at 0x7f2b3df190f0>,
#  <keras.layers.core.Activation at 0x7f2b3df1eb38>,
#  <keras.layers.convolutional.Conv2D at 0x7f2b3df1e390>,
#  <keras.layers.normalization.BatchNormalization at 0x7f2b3df44cc0>,
#  <keras.layers.core.Activation at 0x7f2b3dcbfb00>,
#  <keras.layers.convolutional.Conv2D at 0x7f2b3dcbdd30>,
#  <keras.layers.normalization.BatchNormalization at 0x7f2b3dc9b4a8>,
#  <keras.layers.merge.Add at 0x7f2b3dc9d5c0>,
#  <keras.layers.core.Activation at 0x7f2b3dcc8f28>,
#  <keras.layers.convolutional.Conv2D at 0x7f2b3dcc8a90>,
#  <keras.layers.normalization.BatchNormalization at 0x7f2b3dccfeb8>,
#  <keras.layers.core.Activation at 0x7f2b3dce4710>,
#  <keras.layers.convolutional.Conv2D at 0x7f2b3dd58a90>,
#  <keras.layers.convolutional.Conv2D at 0x7f2b3dd4cc18>,
#  <keras.layers.normalization.BatchNormalization at 0x7f2b3dd7b908>,
#  <keras.layers.merge.Add at 0x7f2b3de34dd8>,
#  <keras.layers.core.Activation at 0x7f2b3de3aa90>,
#  <keras.layers.convolutional.Conv2D at 0x7f2b3de3aba8>,
#  <keras.layers.normalization.BatchNormalization at 0x7f2b3de1cc18>,
#  <keras.layers.core.Activation at 0x7f2b3de1ce10>,
#  <keras.layers.convolutional.Conv2D at 0x7f2b3de445c0>,
#  <keras.layers.normalization.BatchNormalization at 0x7f2b3ddfe278>,
#  <keras.layers.merge.Add at 0x7f2b3ddf82e8>,
#  <keras.layers.core.Activation at 0x7f2b3dde2d30>,
#  <keras.layers.convolutional.Conv2D at 0x7f2b3dde2588>,
#  <keras.layers.normalization.BatchNormalization at 0x7f2b3ddb5eb8>,
#  <keras.layers.core.Activation at 0x7f2b3ddbc400>,
#  <keras.layers.convolutional.Conv2D at 0x7f2b3dda9f28>,
#  <keras.layers.normalization.BatchNormalization at 0x7f2b3dede5f8>,
#  <keras.layers.merge.Add at 0x7f2b3deef6d8>,
#  <keras.layers.core.Activation at 0x7f2b3ded0a90>,
#  <keras.layers.pooling.AveragePooling2D at 0x7f2b3ded0a58>,
#  <keras.layers.core.Flatten at 0x7f2b3dec98d0>]

# %%
layer_names = []
for layer in model.layers[:-1]:
    layer_names.append(layer.name) 
images_per_row = 16
for layer_name, layer_activation in zip(layer_names, activations):
    if layer_name.startswith('conv'):
        n_features = layer_activation.shape[-1]
        size = layer_activation.shape[1]
        n_cols = n_features // images_per_row
        display_grid = np.zeros((size * n_cols, images_per_row * size))
        for col in range(n_cols):
            for row in range(images_per_row):
                channel_image = layer_activation[0,:, :, col * images_per_row + row]
                channel_image -= channel_image.mean()
                channel_image /= channel_image.std()
                channel_image *= 64
                channel_image += 128
                channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                display_grid[col * size : (col + 1) * size,
                             row * size : (row + 1) * size] = channel_image
        scale = 1. / size
        plt.figure(figsize=(scale * display_grid.shape[1],
                            scale * display_grid.shape[0]))
        plt.title(layer_name)
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='viridis')

# %%
layer_names = []
for layer in model.layers[:-1]:
    layer_names.append(layer.name) 
images_per_row = 16
for layer_name, layer_activation in zip(layer_names, activations):
    if layer_name.startswith('batch'):
        n_features = layer_activation.shape[-1]
        size = layer_activation.shape[1]
        n_cols = n_features // images_per_row
        display_grid = np.zeros((size * n_cols, images_per_row * size))
        for col in range(n_cols):
            for row in range(images_per_row):
                channel_image = layer_activation[0,:, :, col * images_per_row + row]
                channel_image -= channel_image.mean()
                channel_image /= channel_image.std()
                channel_image *= 64
                channel_image += 128
                channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                display_grid[col * size : (col + 1) * size,
                             row * size : (row + 1) * size] = channel_image
        scale = 1. / size
        plt.figure(figsize=(scale * display_grid.shape[1],
                            scale * display_grid.shape[0]))
        plt.title(layer_name)
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='viridis')

# %%
layer_names = []
for layer in model.layers[:-1]:
    layer_names.append(layer.name) 
images_per_row = 16
for layer_name, layer_activation in zip(layer_names, activations):
    if layer_name.startswith('activation'):
        n_features = layer_activation.shape[-1]
        size = layer_activation.shape[1]
        n_cols = n_features // images_per_row
        display_grid = np.zeros((size * n_cols, images_per_row * size))
        for col in range(n_cols):
            for row in range(images_per_row):
                channel_image = layer_activation[0,:, :, col * images_per_row + row]
                channel_image -= channel_image.mean()
                channel_image /= channel_image.std()
                channel_image *= 64
                channel_image += 128
                channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                display_grid[col * size : (col + 1) * size,
                             row * size : (row + 1) * size] = channel_image
        scale = 1. / size
        plt.figure(figsize=(scale * display_grid.shape[1],
                            scale * display_grid.shape[0]))
        plt.title(layer_name)
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='viridis')

# %%
# Predict the values from the validation dataset
Y_pred = model.predict(X_test)
# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred, axis = 1)
Y_true_classes = np.argmax(Y_test, axis = 1)

# %%
Y_pred_classes[:5], Y_true_classes[:5]
# Out:
# (array([3, 8, 8, 0, 6]), array([3, 8, 8, 0, 6]))

# %%
from sklearn.metrics import classification_report
target_names = ["Class {}".format(i) for i in range(num_classes)]
print(classification_report(Y_true_classes, Y_pred_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.91      0.92      0.91      1000
#      Class 1       0.94      0.97      0.95      1000
#      Class 2       0.87      0.86      0.87      1000
#      Class 3       0.80      0.80      0.80      1000
#      Class 4       0.92      0.91      0.91      1000
#      Class 5       0.88      0.83      0.85      1000
#      Class 6       0.90      0.95      0.92      1000
#      Class 7       0.94      0.93      0.94      1000
#      Class 8       0.95      0.94      0.95      1000
#      Class 9       0.94      0.94      0.94      1000
#
#     accuracy                           0.91     10000
#    macro avg       0.91      0.91      0.91     10000
# weighted avg       0.91      0.91      0.91     10000

# %%
from keras.models import load_model 
model.save('project_model.h5')
