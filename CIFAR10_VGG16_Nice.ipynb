# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras import optimizers
import numpy as np
from keras.layers.core import Lambda
from keras import backend as K
from keras import regularizers
import matplotlib.pyplot as plt #for plotting
from sklearn.metrics import confusion_matrix
import itertools
from sklearn.model_selection import train_test_split

# %%
#training parameters
batch_size = 64
maxepoches = 100
learning_rate = 0.1
lr_decay = 1e-6
lr_drop = 20
num_classes = 10
# The data, shuffled and split between train and test sets:
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train, X_test = X_train/255, X_test/255

Y_train = keras.utils.to_categorical(Y_train, num_classes)
Y_test = keras.utils.to_categorical(Y_test, num_classes)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 13s 0us/step

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size = 0.1, random_state=42)

# %%
weight_decay = 0.0005
x_shape = [32,32,3]

model = Sequential()

model.add(Conv2D(64, (3, 3), padding='same',input_shape=x_shape,kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Conv2D(64, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(4096,kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(Dense(4096,kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(Dense(512,kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %%
def lr_scheduler(epoch):
    return learning_rate * (0.5 ** (epoch // lr_drop))
reduce_lr = keras.callbacks.LearningRateScheduler(lr_scheduler)

# %%
#data augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    zca_whitening=False,  # apply ZCA whitening
    rotation_range=15,  # randomly rotate images in the range (degrees, 0 to 180)
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
    horizontal_flip=True,  # randomly flip images
    vertical_flip=False)  # randomly flip images
# (std, mean, and principal components if ZCA whitening is applied).
datagen.fit(x_train)

# %%
#optimization details
sgd = optimizers.SGD(lr=learning_rate, decay=lr_decay, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd,metrics=['accuracy'])

# %%
h = model.fit_generator(datagen.flow(x_train, y_train,
                                  batch_size=batch_size),
                    steps_per_epoch=x_train.shape[0] // batch_size,
                    epochs=maxepoches,
                    validation_data=(x_test, y_test),callbacks=[reduce_lr],verbose=2)
# Out:
# Epoch 1/100
#  - 67s - loss: 63.2652 - accuracy: 0.1316 - val_loss: 54.5637 - val_accuracy: 0.0860
# Epoch 2/100
#  - 55s - loss: 17.5297 - accuracy: 0.1868 - val_loss: 10.6750 - val_accuracy: 0.0560
# Epoch 3/100
#  - 55s - loss: 5.7805 - accuracy: 0.2087 - val_loss: 3.7377 - val_accuracy: 0.2238
# Epoch 4/100
#  - 55s - loss: 2.9220 - accuracy: 0.2351 - val_loss: 3.1042 - val_accuracy: 0.1506
# Epoch 5/100
#  - 55s - loss: 2.1728 - accuracy: 0.2914 - val_loss: 2.7034 - val_accuracy: 0.2718
# Epoch 6/100
#  - 55s - loss: 1.9556 - accuracy: 0.3612 - val_loss: 2.0153 - val_accuracy: 0.3854
# Epoch 7/100
#  - 55s - loss: 1.8930 - accuracy: 0.4103 - val_loss: 1.9367 - val_accuracy: 0.4226
# Epoch 8/100
#  - 55s - loss: 1.8266 - accuracy: 0.4853 - val_loss: 1.6355 - val_accuracy: 0.5688
# Epoch 9/100
#  - 55s - loss: 1.8178 - accuracy: 0.5264 - val_loss: 2.1728 - val_accuracy: 0.4262
# Epoch 10/100
#  - 55s - loss: 1.8300 - accuracy: 0.5482 - val_loss: 1.7174 - val_accuracy: 0.5816
# Epoch 11/100
#  - 55s - loss: 1.8670 - accuracy: 0.5579 - val_loss: 1.7901 - val_accuracy: 0.5616
# Epoch 12/100
#  - 55s - loss: 1.9169 - accuracy: 0.5550 - val_loss: 2.1977 - val_accuracy: 0.5012
# Epoch 13/100
#  - 55s - loss: 1.8964 - accuracy: 0.5725 - val_loss: 1.7140 - val_accuracy: 0.6190
# Epoch 14/100
#  - 55s - loss: 1.8855 - accuracy: 0.5805 - val_loss: 1.7858 - val_accuracy: 0.6008
# Epoch 15/100
#  - 55s - loss: 1.9156 - accuracy: 0.5809 - val_loss: 3.1480 - val_accuracy: 0.3568
# Epoch 16/100
#  - 55s - loss: 1.8963 - accuracy: 0.5923 - val_loss: 2.0215 - val_accuracy: 0.5402
# Epoch 17/100
#  - 55s - loss: 1.9495 - accuracy: 0.5860 - val_loss: 2.1674 - val_accuracy: 0.5274
# Epoch 18/100
#  - 55s - loss: 1.9255 - accuracy: 0.5978 - val_loss: 2.2287 - val_accuracy: 0.4802
# Epoch 19/100
#  - 55s - loss: 1.9555 - accuracy: 0.5970 - val_loss: 1.7835 - val_accuracy: 0.6434
# Epoch 20/100
#  - 55s - loss: 1.9334 - accuracy: 0.6075 - val_loss: 2.2628 - val_accuracy: 0.5486
# Epoch 21/100
#  - 55s - loss: 1.7048 - accuracy: 0.6658 - val_loss: 1.5614 - val_accuracy: 0.6860
# Epoch 22/100
#  - 55s - loss: 1.6088 - accuracy: 0.6773 - val_loss: 1.4150 - val_accuracy: 0.7248
# Epoch 23/100
#  - 55s - loss: 1.6100 - accuracy: 0.6771 - val_loss: 1.4227 - val_accuracy: 0.7206
# Epoch 24/100
#  - 55s - loss: 1.5999 - accuracy: 0.6844 - val_loss: 1.5999 - val_accuracy: 0.6932
# Epoch 25/100
#  - 55s - loss: 1.6034 - accuracy: 0.6909 - val_loss: 1.6201 - val_accuracy: 0.6780
# Epoch 26/100
#  - 55s - loss: 1.6210 - accuracy: 0.6953 - val_loss: 1.4522 - val_accuracy: 0.7418
# Epoch 27/100
#  - 55s - loss: 1.6085 - accuracy: 0.6949 - val_loss: 1.4333 - val_accuracy: 0.7540
# Epoch 28/100
#  - 55s - loss: 1.6282 - accuracy: 0.7005 - val_loss: 1.4787 - val_accuracy: 0.7380
# Epoch 29/100
#  - 55s - loss: 1.6076 - accuracy: 0.7043 - val_loss: 1.4475 - val_accuracy: 0.7562
# Epoch 30/100
#  - 55s - loss: 1.6158 - accuracy: 0.7081 - val_loss: 1.6299 - val_accuracy: 0.7002
# Epoch 31/100
#  - 55s - loss: 1.6361 - accuracy: 0.7067 - val_loss: 1.5553 - val_accuracy: 0.7242
# Epoch 32/100
#  - 55s - loss: 1.6301 - accuracy: 0.7126 - val_loss: 1.5575 - val_accuracy: 0.7224
# Epoch 33/100
#  - 55s - loss: 1.6301 - accuracy: 0.7125 - val_loss: 1.8931 - val_accuracy: 0.6132
# Epoch 34/100
#  - 55s - loss: 1.6105 - accuracy: 0.7177 - val_loss: 1.9373 - val_accuracy: 0.6398
# Epoch 35/100
#  - 55s - loss: 1.6186 - accuracy: 0.7203 - val_loss: 1.6213 - val_accuracy: 0.7098
# Epoch 36/100
#  - 55s - loss: 1.6244 - accuracy: 0.7228 - val_loss: 1.4853 - val_accuracy: 0.7672
# Epoch 37/100
#  - 55s - loss: 1.7704 - accuracy: 0.6914 - val_loss: 1.5821 - val_accuracy: 0.7556
# Epoch 38/100
#  - 55s - loss: 1.7053 - accuracy: 0.7142 - val_loss: 1.5207 - val_accuracy: 0.7564
# Epoch 39/100
#  - 55s - loss: 1.6646 - accuracy: 0.7160 - val_loss: 1.6044 - val_accuracy: 0.7288
# Epoch 40/100
#  - 55s - loss: 1.6480 - accuracy: 0.7221 - val_loss: 1.7198 - val_accuracy: 0.6856
# Epoch 41/100
#  - 55s - loss: 1.4532 - accuracy: 0.7636 - val_loss: 1.3299 - val_accuracy: 0.7824
# Epoch 42/100
#  - 55s - loss: 1.3540 - accuracy: 0.7742 - val_loss: 1.2997 - val_accuracy: 0.7828
# Epoch 43/100
#  - 55s - loss: 1.3270 - accuracy: 0.7728 - val_loss: 1.2718 - val_accuracy: 0.7822
# Epoch 44/100
#  - 55s - loss: 1.3225 - accuracy: 0.7718 - val_loss: 1.8283 - val_accuracy: 0.6306
# Epoch 45/100
#  - 55s - loss: 1.3271 - accuracy: 0.7710 - val_loss: 1.1831 - val_accuracy: 0.8078
# Epoch 46/100
#  - 55s - loss: 1.3192 - accuracy: 0.7736 - val_loss: 1.1979 - val_accuracy: 0.8022
# Epoch 47/100
#  - 55s - loss: 1.3156 - accuracy: 0.7772 - val_loss: 1.2743 - val_accuracy: 0.7844
# Epoch 48/100
#  - 55s - loss: 1.3293 - accuracy: 0.7740 - val_loss: 1.3695 - val_accuracy: 0.7546
# Epoch 49/100
#  - 55s - loss: 1.3238 - accuracy: 0.7806 - val_loss: 1.2292 - val_accuracy: 0.7980
# Epoch 50/100
#  - 55s - loss: 1.3251 - accuracy: 0.7791 - val_loss: 1.2429 - val_accuracy: 0.8030
# Epoch 51/100
#  - 55s - loss: 1.3296 - accuracy: 0.7807 - val_loss: 1.3170 - val_accuracy: 0.7760
# Epoch 52/100
#  - 55s - loss: 1.3389 - accuracy: 0.7804 - val_loss: 1.2500 - val_accuracy: 0.7998
# Epoch 53/100
#  - 55s - loss: 1.3369 - accuracy: 0.7804 - val_loss: 1.3268 - val_accuracy: 0.7754
# Epoch 54/100
#  - 55s - loss: 1.3357 - accuracy: 0.7836 - val_loss: 1.2543 - val_accuracy: 0.7974
# Epoch 55/100
#  - 55s - loss: 1.3271 - accuracy: 0.7870 - val_loss: 1.4689 - val_accuracy: 0.7316
# Epoch 56/100
#  - 55s - loss: 1.3259 - accuracy: 0.7860 - val_loss: 1.3162 - val_accuracy: 0.7844
# Epoch 57/100
#  - 55s - loss: 1.3423 - accuracy: 0.7863 - val_loss: 1.3545 - val_accuracy: 0.7772
# Epoch 58/100
#  - 55s - loss: 1.3238 - accuracy: 0.7916 - val_loss: 1.3944 - val_accuracy: 0.7628
# Epoch 59/100
#  - 55s - loss: 1.3431 - accuracy: 0.7864 - val_loss: 1.2212 - val_accuracy: 0.8194
# Epoch 60/100
#  - 55s - loss: 1.3407 - accuracy: 0.7874 - val_loss: 1.3194 - val_accuracy: 0.7922
# Epoch 61/100
#  - 55s - loss: 1.2022 - accuracy: 0.8237 - val_loss: 1.0277 - val_accuracy: 0.8646
# Epoch 62/100
#  - 55s - loss: 1.1278 - accuracy: 0.8303 - val_loss: 1.0460 - val_accuracy: 0.8522
# Epoch 63/100
#  - 55s - loss: 1.1047 - accuracy: 0.8299 - val_loss: 0.9986 - val_accuracy: 0.8566
# Epoch 64/100
#  - 55s - loss: 1.0782 - accuracy: 0.8310 - val_loss: 1.0030 - val_accuracy: 0.8498
# Epoch 65/100
#  - 55s - loss: 1.0613 - accuracy: 0.8331 - val_loss: 0.9660 - val_accuracy: 0.8540
# Epoch 66/100
#  - 55s - loss: 1.0630 - accuracy: 0.8293 - val_loss: 0.9501 - val_accuracy: 0.8556
# Epoch 67/100
#  - 55s - loss: 1.0603 - accuracy: 0.8308 - val_loss: 0.9794 - val_accuracy: 0.8560
# Epoch 68/100
#  - 55s - loss: 1.0617 - accuracy: 0.8307 - val_loss: 0.9750 - val_accuracy: 0.8530
# Epoch 69/100
#  - 55s - loss: 1.0542 - accuracy: 0.8333 - val_loss: 1.0010 - val_accuracy: 0.8464
# Epoch 70/100
#  - 55s - loss: 1.0603 - accuracy: 0.8295 - val_loss: 0.9655 - val_accuracy: 0.8606
# Epoch 71/100
#  - 55s - loss: 1.0555 - accuracy: 0.8328 - val_loss: 0.9507 - val_accuracy: 0.8638
# Epoch 72/100
#  - 56s - loss: 1.0533 - accuracy: 0.8355 - val_loss: 1.2283 - val_accuracy: 0.7852
# Epoch 73/100
#  - 55s - loss: 1.0505 - accuracy: 0.8353 - val_loss: 0.9287 - val_accuracy: 0.8690
# Epoch 74/100
#  - 55s - loss: 1.0633 - accuracy: 0.8320 - val_loss: 1.0324 - val_accuracy: 0.8338
# Epoch 75/100
#  - 55s - loss: 1.0461 - accuracy: 0.8389 - val_loss: 0.9631 - val_accuracy: 0.8602
# Epoch 76/100
#  - 55s - loss: 1.0534 - accuracy: 0.8346 - val_loss: 1.0245 - val_accuracy: 0.8424
# Epoch 77/100
#  - 55s - loss: 1.0613 - accuracy: 0.8364 - val_loss: 1.0811 - val_accuracy: 0.8248
# Epoch 78/100
#  - 55s - loss: 1.0645 - accuracy: 0.8356 - val_loss: 0.9538 - val_accuracy: 0.8656
# Epoch 79/100
#  - 55s - loss: 1.0602 - accuracy: 0.8388 - val_loss: 1.0425 - val_accuracy: 0.8398
# Epoch 80/100
#  - 55s - loss: 1.0609 - accuracy: 0.8386 - val_loss: 0.9831 - val_accuracy: 0.8626
# Epoch 81/100
#  - 55s - loss: 0.9732 - accuracy: 0.8616 - val_loss: 0.9018 - val_accuracy: 0.8782
# Epoch 82/100
#  - 55s - loss: 0.9122 - accuracy: 0.8759 - val_loss: 0.8142 - val_accuracy: 0.9018
# Epoch 83/100
#  - 55s - loss: 0.8954 - accuracy: 0.8739 - val_loss: 0.8510 - val_accuracy: 0.8870
# Epoch 84/100
#  - 55s - loss: 0.8804 - accuracy: 0.8744 - val_loss: 0.8880 - val_accuracy: 0.8672
# Epoch 85/100
#  - 55s - loss: 0.8602 - accuracy: 0.8758 - val_loss: 0.7981 - val_accuracy: 0.8912
# Epoch 86/100
#  - 55s - loss: 0.8721 - accuracy: 0.8715 - val_loss: 0.8435 - val_accuracy: 0.8786
# Epoch 87/100
#  - 55s - loss: 0.8491 - accuracy: 0.8761 - val_loss: 0.8128 - val_accuracy: 0.8882
# Epoch 88/100
#  - 55s - loss: 0.8457 - accuracy: 0.8750 - val_loss: 0.7874 - val_accuracy: 0.8902
# Epoch 89/100
#  - 55s - loss: 0.8544 - accuracy: 0.8713 - val_loss: 0.7713 - val_accuracy: 0.8974
# Epoch 90/100
#  - 55s - loss: 0.8354 - accuracy: 0.8758 - val_loss: 0.7970 - val_accuracy: 0.8854
# Epoch 91/100
#  - 55s - loss: 0.8316 - accuracy: 0.8765 - val_loss: 0.7503 - val_accuracy: 0.8966
# Epoch 92/100
#  - 55s - loss: 0.8261 - accuracy: 0.8751 - val_loss: 0.7535 - val_accuracy: 0.9006
# Epoch 93/100
#  - 55s - loss: 0.8506 - accuracy: 0.8692 - val_loss: 0.8039 - val_accuracy: 0.8790
# Epoch 94/100
#  - 55s - loss: 0.8377 - accuracy: 0.8744 - val_loss: 0.7933 - val_accuracy: 0.8842
# Epoch 95/100
#  - 55s - loss: 0.8261 - accuracy: 0.8772 - val_loss: 0.7851 - val_accuracy: 0.8830
# Epoch 96/100
#  - 55s - loss: 0.8505 - accuracy: 0.8719 - val_loss: 0.7681 - val_accuracy: 0.8950
# Epoch 97/100
#  - 55s - loss: 0.8327 - accuracy: 0.8764 - val_loss: 0.7762 - val_accuracy: 0.8946
# Epoch 98/100
#  - 55s - loss: 0.8295 - accuracy: 0.8785 - val_loss: 0.8063 - val_accuracy: 0.8872
# Epoch 99/100
#  - 55s - loss: 0.8307 - accuracy: 0.8761 - val_loss: 0.8459 - val_accuracy: 0.8706
# Epoch 100/100
#  - 55s - loss: 0.8309 - accuracy: 0.8757 - val_loss: 0.8230 - val_accuracy: 0.8772

# %%
final_loss, final_acc = model.evaluate(X_test, Y_test, verbose=0)
print("Final loss: {0:.6f}, final accuracy: {1:.6f}".format(final_loss, final_acc))
# Out:
# Final loss: 0.859706, final accuracy: 0.864900

# %%
from keras.models import load_model 
model.save('drive/My Drive/VGG16_CIFAR10_Nice.h5')

# %%
# Look at confusion matrix 
#Note, this code is taken straight from the SKLEARN website, an nice way of viewing confusion matrix.
import numpy as np
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Predict the values from the validation dataset
Y_pred = model.predict(x_test)
# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred, axis = 1) 
# Convert validation observations to one hot vectors
Y_true = np.argmax(y_test, axis = 1) 
# compute the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
# plot the confusion matrix
plot_confusion_matrix(confusion_mtx, classes = range(10))

# %%
print(h.history.keys())
accuracy = h.history['accuracy']
val_accuracy = h.history['val_accuracy']
loss = h.history['loss']
val_loss = h.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.show()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy', 'lr'])

# %%
def categ(i):
  if i==0: 
      return "Aeroplane" 
  elif i==1: 
      return'Automobile' 
  elif i==2: 
      return'Bird' 
  elif i==3: 
      return'Cat' 
  elif i==4: 
      return'Deer' 
  elif i==5: 
      return'Dog' 
  elif i==6: 
      return'Frog' 
  elif i==7: 
      return'Horse' 
  elif i==8: 
      return 'Ship' 
  elif i==9: 
      return 'Truck' 
  else: 
      return 'Error'

# %%
# Errors are difference between predicted labels and true labels
errors = (Y_pred_classes - Y_true != 0)

Y_pred_classes_errors = Y_pred_classes[errors]
Y_pred_errors = Y_pred[errors]
Y_true_errors = Y_true[errors]
X_val_errors = x_test[errors]

def display_errors(errors_index,img_errors,pred_errors, obs_errors):
    """ This function shows 6 images with their predicted and real labels"""
    n = 0
    nrows = 2
    ncols = 3
    fig, ax = plt.subplots(nrows,ncols,sharex=True)
    fig.tight_layout()
    for row in range(nrows):
        for col in range(ncols):
            error = errors_index[n]
            ax[row,col].imshow((img_errors[error]).reshape((32,32,3)))
            
            ax[row,col].set_title("\nPredicted:{}\nTrue label :{}".format(categ(pred_errors[error]),categ(obs_errors[error])))
            
            # subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=None)
            n += 1

# Probabilities of the wrong predicted numbers
Y_pred_errors_prob = np.max(Y_pred_errors,axis = 1)

# Predicted probabilities of the true values in the error set
true_prob_errors = np.diagonal(np.take(Y_pred_errors, Y_true_errors, axis=1))

# Difference between the probability of the predicted label and the true label
delta_pred_true_errors = Y_pred_errors_prob - true_prob_errors

# Sorted list of the delta prob errors
sorted_dela_errors = np.argsort(delta_pred_true_errors)

# Top 6 errors 
most_important_errors = sorted_dela_errors[-6:]

# Show the top 6 errors
display_errors(most_important_errors, X_val_errors, Y_pred_classes_errors, Y_true_errors)

# %%
test_im = x_train[15]
plt.imshow(test_im.reshape(32,32,3), cmap='viridis', interpolation='none')

# %%
from keras import models
layer_outputs = [layer.output for layer in model.layers[:8]]
activation_model = models.Model(input=model.input, output=layer_outputs)
activations = activation_model.predict(test_im.reshape(1,32,32,3))

first_layer_activation = activations[4]
plt.matshow(first_layer_activation[0, :, :, 4], cmap='viridis')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("co..., outputs=[<tf.Tenso...)`
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
model.layers[:-1]
# Out:
# [<keras.layers.convolutional.Conv2D at 0x7f86cef4ef60>,
#  <keras.layers.core.Activation at 0x7f86cef4ef98>,
#  <keras.layers.normalization.BatchNormalization at 0x7f86cef67240>,
#  <keras.layers.core.Dropout at 0x7f86cef67320>,
#  <keras.layers.convolutional.Conv2D at 0x7f86c050f0f0>,
#  <keras.layers.core.Activation at 0x7f86cef672e8>,
#  <keras.layers.normalization.BatchNormalization at 0x7f86c0533cc0>,
#  <keras.layers.pooling.MaxPooling2D at 0x7f86c0533b38>,
#  <keras.layers.convolutional.Conv2D at 0x7f86c0533668>,
#  <keras.layers.core.Activation at 0x7f86c04919e8>,
#  <keras.layers.normalization.BatchNormalization at 0x7f86c04ad940>,
#  <keras.layers.core.Dropout at 0x7f86c04ad7b8>,
#  <keras.layers.convolutional.Conv2D at 0x7f86c04b8978>,
#  <keras.layers.core.Activation at 0x7f86c04ad2e8>,
#  <keras.layers.normalization.BatchNormalization at 0x7f86c0461ba8>,
#  <keras.layers.pooling.MaxPooling2D at 0x7f86c0461a20>,
#  <keras.layers.convolutional.Conv2D at 0x7f86c0403f60>,
#  <keras.layers.core.Activation at 0x7f86c0425160>,
#  <keras.layers.normalization.BatchNormalization at 0x7f86c0425278>,
#  <keras.layers.core.Dropout at 0x7f86c0432278>,
#  <keras.layers.convolutional.Conv2D at 0x7f86c03c2dd8>,
#  <keras.layers.core.Activation at 0x7f86c0425e10>,
#  <keras.layers.normalization.BatchNormalization at 0x7f86c03c95f8>,
#  <keras.layers.core.Dropout at 0x7f86c03da3c8>,
#  <keras.layers.convolutional.Conv2D at 0x7f86c03dadd8>,
#  <keras.layers.core.Activation at 0x7f86c03da5c0>,
#  <keras.layers.normalization.BatchNormalization at 0x7f86c0391fd0>,
#  <keras.layers.pooling.MaxPooling2D at 0x7f86c0391be0>,
#  <keras.layers.convolutional.Conv2D at 0x7f86c0387dd8>,
#  <keras.layers.core.Activation at 0x7f86c0345c88>,
#  <keras.layers.normalization.BatchNormalization at 0x7f86c035e630>,
#  <keras.layers.core.Dropout at 0x7f86c035e438>,
#  <keras.layers.convolutional.Conv2D at 0x7f86c037a978>,
#  <keras.layers.core.Activation at 0x7f86c035ee48>,
#  <keras.layers.normalization.BatchNormalization at 0x7f86c0315940>,
#  <keras.layers.core.Dropout at 0x7f86c03157b8>,
#  <keras.layers.convolutional.Conv2D at 0x7f86c03152e8>,
#  <keras.layers.core.Activation at 0x7f86c03158d0>,
#  <keras.layers.normalization.BatchNormalization at 0x7f86c02c96a0>,
#  <keras.layers.pooling.MaxPooling2D at 0x7f86c02d8390>,
#  <keras.layers.convolutional.Conv2D at 0x7f86c02d8c88>,
#  <keras.layers.core.Activation at 0x7f86c02fdfd0>,
#  <keras.layers.normalization.BatchNormalization at 0x7f86c0298940>,
#  <keras.layers.core.Dropout at 0x7f86c02987b8>,
#  <keras.layers.convolutional.Conv2D at 0x7f86c02a59e8>,
#  <keras.layers.core.Activation at 0x7f86c02982e8>,
#  <keras.layers.normalization.BatchNormalization at 0x7f86c024ccc0>,
#  <keras.layers.core.Dropout at 0x7f86c024cb38>,
#  <keras.layers.convolutional.Conv2D at 0x7f86c0279390>,
#  <keras.layers.core.Activation at 0x7f86c024cc50>,
#  <keras.layers.normalization.BatchNormalization at 0x7f86c02804e0>,
#  <keras.layers.pooling.MaxPooling2D at 0x7f86c0213358>,
#  <keras.layers.core.Dropout at 0x7f86c0213550>,
#  <keras.layers.core.Flatten at 0x7f86c023d4e0>,
#  <keras.layers.core.Dense at 0x7f86c023d2b0>,
#  <keras.layers.core.Activation at 0x7f86c023dcc0>,
#  <keras.layers.core.Dense at 0x7f86c01ff9e8>,
#  <keras.layers.core.Activation at 0x7f86c01ff978>,
#  <keras.layers.core.Dense at 0x7f86c0201518>,
#  <keras.layers.core.Activation at 0x7f86c0201e80>,
#  <keras.layers.normalization.BatchNormalization at 0x7f86c018b5c0>,
#  <keras.layers.core.Dropout at 0x7f86c018b710>,
#  <keras.layers.core.Dense at 0x7f86c0195b70>]

# %%
layer_names = []
for layer in model.layers[:-1]:
    layer_names.append(layer.name) 
images_per_row = 16
for layer_name, layer_activation in zip(layer_names, activations):
    if layer_name.startswith('conv'):
        n_features = layer_activation.shape[-1]
        size = layer_activation.shape[1]
        n_cols = n_features // images_per_row
        display_grid = np.zeros((size * n_cols, images_per_row * size))
        for col in range(n_cols):
            for row in range(images_per_row):
                channel_image = layer_activation[0,:, :, col * images_per_row + row]
                channel_image -= channel_image.mean()
                channel_image /= channel_image.std()
                channel_image *= 64
                channel_image += 128
                channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                display_grid[col * size : (col + 1) * size,
                             row * size : (row + 1) * size] = channel_image
        scale = 1. / size
        plt.figure(figsize=(scale * display_grid.shape[1],
                            scale * display_grid.shape[0]))
        plt.title(layer_name)
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='viridis')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in true_divide
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in true_divide
#   from ipykernel import kernelapp as app

# %%
layer_names = []
for layer in model.layers[:-1]:
    layer_names.append(layer.name) 
images_per_row = 16
for layer_name, layer_activation in zip(layer_names, activations):
    if layer_name.startswith('max'):
        n_features = layer_activation.shape[-1]
        size = layer_activation.shape[1]
        n_cols = n_features // images_per_row
        display_grid = np.zeros((size * n_cols, images_per_row * size))
        for col in range(n_cols):
            for row in range(images_per_row):
                channel_image = layer_activation[0,:, :, col * images_per_row + row]
                channel_image -= channel_image.mean()
                channel_image /= channel_image.std()
                channel_image *= 64
                channel_image += 128
                channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                display_grid[col * size : (col + 1) * size,
                             row * size : (row + 1) * size] = channel_image
        scale = 1. / size
        plt.figure(figsize=(scale * display_grid.shape[1],
                            scale * display_grid.shape[0]))
        plt.title(layer_name)
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='viridis')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in true_divide
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in true_divide
#   app.launch_new_instance()

# %%
layer_names = []
for layer in model.layers[:-1]:
    layer_names.append(layer.name) 
images_per_row = 16
for layer_name, layer_activation in zip(layer_names, activations):
    if layer_name.startswith('drop'):
        n_features = layer_activation.shape[-1]
        size = layer_activation.shape[1]
        n_cols = n_features // images_per_row
        display_grid = np.zeros((size * n_cols, images_per_row * size))
        for col in range(n_cols):
            for row in range(images_per_row):
                channel_image = layer_activation[0,:, :, col * images_per_row + row]
                channel_image -= channel_image.mean()
                channel_image /= channel_image.std()
                channel_image *= 64
                channel_image += 128
                channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                display_grid[col * size : (col + 1) * size,
                             row * size : (row + 1) * size] = channel_image
        scale = 1. / size
        plt.figure(figsize=(scale * display_grid.shape[1],
                            scale * display_grid.shape[0]))
        plt.title(layer_name)
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='viridis')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in true_divide
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in true_divide
#   from ipykernel import kernelapp as app

# %%
# Predict the values from the validation dataset
Y_pred = model.predict(x_test)
# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred, axis = 1)
Y_true_classes = np.argmax(y_test, axis = 1)

# %%
Y_pred_classes[:5], Y_true_classes[:5]
# Out:
# (array([7, 8, 0, 6, 1]), array([7, 8, 0, 6, 1]))

# %%
from sklearn.metrics import classification_report
target_names = ["Class {}".format(i) for i in range(num_classes)]
print(classification_report(Y_true_classes, Y_pred_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.93      0.88       476
#      Class 1       0.90      0.99      0.94       487
#      Class 2       0.85      0.86      0.86       527
#      Class 3       0.83      0.72      0.77       523
#      Class 4       0.91      0.88      0.90       486
#      Class 5       0.93      0.70      0.80       504
#      Class 6       0.77      0.98      0.86       485
#      Class 7       0.89      0.94      0.91       509
#      Class 8       0.95      0.91      0.93       503
#      Class 9       0.96      0.89      0.92       500
#
#     accuracy                           0.88      5000
#    macro avg       0.88      0.88      0.88      5000
# weighted avg       0.88      0.88      0.88      5000

# %%
from keras.models import load_model 
model.save('drive/My Drive/project_model.h5')
